# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam00242/python-class-cbitss/blob/main/square_root.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sum=0
for i in range (1,11):
  sum+=i**2
  print(sum)

# %%
sum=0
for i in range (1,11):
  sum+=i**5
  print(sum)

# %%
sum1=0
sum2=0
for i in range (1,10,2):
  sum1+=i**2
  print(sum1)
for i in range (2,11,2):
  sum2+=i**3
  print(sum2)
print(sum1+sum2)

# %%
# when we have underroot value to solve
sum=0
sum+=16**(1/4)+81**(1/4)+256**(1/4)+625**(1/4)
print(sum)

# %%
# list comprehsion
a=[i for i in range(10) if i%2!=0]
print(a)

# %%
a=[i*i for i in range(10) if i%2!=0]
print(a)
