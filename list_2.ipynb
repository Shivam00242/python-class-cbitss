# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam00242/python-class-cbitss/blob/main/list_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list=[1,5,4,7,8]
sum=0
for i in range (0,len(list)):
  sum=sum+list[i]
print(sum)
# Out:
# 25

# %%
list=[4,5,6,7,8]
sum=0
for i in list:
  sum=sum+i
print(sum)
# Out:
# 30

# %%
#  restaurant bill with for loop
item=['pizza','pasta','chips','coke','dal chawal']
price=[450,250,40,80,150]
qty=[1,1,2,2,2]
discount=[12,21,25,32,11]

total_bill=0
total_bill_after_discount=0
print("_________One8 Commune________")
for i in range (0,len(item)):
  item_total=price[i]*qty[i]
  item_discount=(item_total*discount[i])/100
  item_after_discount=item_total-item_discount

  print("_________________  ",
        "\nitem=",item[i],
        "\n price=",price[i],
        "\n qty=",qty[i],
        "\n discount =",item_discount,
        "\n --------------"
        "\n item total=",item_after_discount,
        "\n")
  total_bill=total_bill+item_total
  total_bill_after_discount=total_bill_after_discount+item_after_discount


print("____________________",
      "\n total bill=",total_bill,
      "\n total bill after discount=",total_bill_after_discount
      )
# Out:
# _________One8 Commune________
# _________________
# item= pizza
#  price= 450
#  qty= 1
#  discount = 54.0
#  --------------
#  item total= 396.0
#
# _________________
# item= pasta
#  price= 250
#  qty= 1
#  discount = 52.5
#  --------------
#  item total= 197.5
#
# _________________
# item= chips
#  price= 40
#  qty= 2
#  discount = 20.0
#  --------------
#  item total= 60.0
#
# _________________
# item= coke
#  price= 80
#  qty= 2
#  discount = 51.2
#  --------------
#  item total= 108.8
#
# _________________
# item= dal chawal
#  price= 150
#  qty= 2
#  discount = 33.0
#  --------------
#  item total= 267.0
#
# ____________________
#  total bill= 1240
#  total bill after discount= 1029.3

# %%
item=['d','f','g','i']
for i in range(0,len(item)):
  print(item[i])
# Out:
# d
# f
# g
# i

# %%
items=[]
prices=[]
qtys=[]
discounts=[]

n=int(input("Enter number of items ="))

for i in range(n):
  item=input(f"enter item no {i+1}:")
  items.append(item)
  price=int(input(f"enter price of item {i+1}:"))
  prices.append(price)
  qty=int(input(f"enter qty of item {i+1}="))
  qtys.append(qty)
  discount=int(input(f"enter discount of item {i+1}="))
  discounts.append(discount)

total_bill=0
total_bill_after_discount=0
print("_________One8 Commune________")
for i in range (0,len(items)):
  item_total=prices[i]*qtys[i]
  item_discount=(item_total*discounts[i])/100
  item_after_discount=item_total-item_discount

  print("_________________  ",
        "\nitem=",items[i],
        "\n price=",prices[i],
        "\n qty=",qtys[i],
        "\n discount =",item_discount,
        "\n --------------"
        "\n item total=",item_after_discount,
        "\n")
  total_bill=total_bill+item_total
  total_bill_after_discount=total_bill_after_discount+item_after_discount
coupons=["SHIVAM_100","ROBIN_150"]
coupons_discount=[100,150]
coupon=input("enter coupon code=")
if coupon in coupons:
  coupon_index=coupons.index(coupon)
  discount_index=coupons_discount[coupon_index]
  total_bill_after_coupon=total_bill_after_discount-discount_index
  print("____________________",
      "\n total bill=",total_bill,
      "\n total bill after discount =",total_bill_after_discount,
      "\n coupon applied successfully:",coupon_index,
      "\n ___________________"
      "\n total bill after coupon discount=",total_bill_after_coupon
      )
else:
 print("____________________",
       "\n unvalid coupon"

      "\n total bill=",total_bill,
      "\n total discount=",item_after_discount,
      "\n ___________________"
      "\n total bill after discount=",total_bill_after_coupon
      )
# Out:
# Enter number of items =1
# enter item no 1:gb
# enter price of item 1:554
# enter qty of item 1=1
# enter discount of item 1=65
# _________One8 Commune________
# _________________
# item= gb
#  price= 554
#  qty= 1
#  discount = 360.1
#  --------------
#  item total= 193.89999999999998
#
# enter coupon code=hvhnug
# ____________________
#  unvalid coupon
#  total bill= 554
#  total discount= 193.89999999999998
#  ___________________
#  total bill after discount= 193.89999999999998

# %%
c_name=["shivam","robin","aman","parth","aryan","shubham","saksham"]
c_id=['101','102','103','104','105','106','107']
product=["shirt","t-shirt","iphone 17","samsung s25 ultra","shirt","t-shirt","iphone 17"]
price=[2500,1500,150000,170000,1200,1500,149999]
state=["hp","pb","hr","hr","hp","pb","hp"]
gender=["m","f","f","m","m","f","m"]

unique_state=[]
state_wise_sale={}
for a in state:
  if a not in unique_state:
    unique_state.append(a)
print(unique_state)
for i in range (len(state)):
  current_sate=state[i]
  current_price=price[i]
  if current_sate not in state_wise_sale:
    state_wise_sale[current_sate]=0
  state_wise_sale[current_sate]+=current_price
print(state_wise_sale)
# Out:
# ['hp', 'pb', 'hr']
# {'hp': 153699, 'pb': 3000, 'hr': 320000}

# %%
import matplotlib.pyplot as plt


c_name=["shivam","robin","aman","parth","aryan","shubham","saksham"]
c_id=['101','102','103','104','105','106','107']
product=["shirt","t-shirt","iphone 17","samsung s25 ultra","shirt","t-shirt","iphone 17"]
price=[2500,150000,150000,17000,1200,1500,149999]
state=["hp","pb","hr","hr","hp","pb","hp"]
gender=["m","f","f","m","m","f","m"]

unique_state=[]
state_wise_sale_=[]
for a in state:
  if a not in unique_state:
    unique_state.append(a)
    state_wise_sale_.append(0)
for i in range(len(price)):
  index=unique_state.index(state[i])
  state_wise_sale_[index]=state_wise_sale_[index]+price[i]

print(unique_state)
print(state_wise_sale_)
plt.bar(unique_state,state_wise_sale_)
plt.show()
# Out:
# ['hp', 'pb', 'hr']
# [153699, 151500, 167000]

# %%
import matplotlib.pyplot as plt


c_name=["shivam","robin","aman","parth","aryan","shubham","saksham"]
c_id=['101','102','103','104','105','106','107']
product=["shirt","t-shirt","iphone 17","samsung s25 ultra","shirt","t-shirt","iphone 17"]
price=[2500,150000,150000,17000,1200,1500,149999]
state=["hp","pb","hr","hr","hp","pb","hp"]
gender=["m","f","f","m","m","f","m"]

unique_product=[]
product_wise_sale_=[]
for a in product:
  if a not in unique_product:
    unique_product.append(a)
    product_wise_sale_.append(0)
for i in range (len(price)):
  index=unique_product.index(product[i])
  product_wise_sale_[index]=product_wise_sale_[index]+price[i]

plt.bar(unique_product,product_wise_sale_)
plt.show()

# %%
import matplotlib.pyplot as plt


c_name=["shivam","robin","aman","parth","aryan","shubham","saksham"]
c_id=['101','102','103','104','105','106','107']
product=["shirt","t-shirt","iphone 17","samsung s25 ultra","shirt","t-shirt","iphone 17"]
price=[2500,150000,150000,17000,1200,1500,149999]
state=["hp","pb","hr","hr","hp","pb","hp"]
gender=["m","f","f","m","m","f","m"]

unique_gender=[]
gender_wise_sale_=[]
for a in gender:
  if a not in unique_gender:
    unique_gender.append(a)
    gender_wise_sale_.append(0)
for i in range(len(price)):
  index=unique_gender.index(gender[i])
  gender_wise_sale_[index]+=price[i]

plt.bar(unique_gender,gender_wise_sale_)
plt.show()

# %%
name= 'shivam'
runs=[101,120,52,68,92,150,250,66,85,25]
country=['aus','pak','sl','nz','pak','sl','aus','wi','sa','pak']
place=['home','home','outside','outside','home','outside','outside','home','outside','home']

unique_country=[]
country_wise_run=[]
unique_place=[]
place_wise_run=[]
country_wise_avg=[]
place_wise_avg=[]
for i in country:
  if i not in unique_country:
    unique_country.append(i)
    country_wise_run.append(0)
for i in range (len(runs)):
  index=unique_country.index(country[i])
  country_wise_run[index]+=runs[i]

for i in place:
  if i not in unique_place:
    unique_place.append(i)
    place_wise_run.append(0)
for i in range(len(runs)):
  index=unique_place.index(place[i])
  place_wise_run[index]+=runs[i]


total_run=sum(runs)
print("total run =",total_run)
print("avg of all time=",total_run/len(runs))
for i in range (len(runs)):
  index=unique_place.index(place[i])
  country_wise_run[index]+=runs[i]

for i in country:

#  country wise avg
print(unique_country)
print(country_wise_run)

print(unique_place)
print(place_wise_run)
# Out:
# total run = 1009
# avg of all time= 100.9
# ['aus', 'pak', 'sl', 'nz', 'wi', 'sa']
# [755, 842, 202, 68, 66, 85]
# ['home', 'outside']
# [404, 605]
