# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam00242/python-class-cbitss/blob/main/whileloop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # while loop
# n=5
# while n>0:
#   print(n)
#   n=n-1
n=4
while n<5 :
  print(n)
  n=n*2

# %%
num=2345
reverse=0
while num>0:
  disit=num % 10
  num=num // 10
  print(disit)
  # reverse of num 2345
  reverse=reverse*10+disit
print(reverse)
# Out:
# 5
# 4
# 3
# 2
# 5432
