# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam00242/python-class-cbitss/blob/main/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
me="shivam is my name"
print(me[:11])
# Out:
# shivam is m

# %%
# square root
print(2116**0.5)
# Out:
# 46.0

# %%
x="mainhoon"
y="kaise ho"
z="kabhi:kabhi"
a="humhihunhai"
f="oyeraju"
print(x[4:8])
print(z[2:5])
print(a[0:6])
print(f[0:3])
if "ho" in y:
  print("yo")
else:
  print("no")
# Out:
# hoon
# bhi
# humhih
# oye
# yo
